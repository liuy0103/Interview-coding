# %%
import torch
import torch.nn.functional as F

score = torch.randn(5,4,3,2)
score
# Out:
# tensor([[[[ 7.4515e-01,  1.2957e+00],
#           [ 3.4830e-03,  9.2297e-01],
#           [ 1.2731e+00, -1.1966e+00]],
#
#          [[ 1.8865e-01, -2.2348e-01],
#           [-1.1026e+00,  1.7297e-01],
#           [ 5.7281e-03, -1.1408e+00]],
#
#          [[-2.2202e-01, -2.0057e+00],
#           [ 9.4231e-01, -5.2234e-01],
#           [ 7.0934e-01, -6.5033e-01]],
#
#          [[-1.2689e+00,  9.0923e-01],
#           [ 1.9819e-01,  1.5017e-02],
#           [ 1.6173e+00, -5.7440e-01]]],
#
#
#         [[[ 8.1819e-01,  3.6501e-01],
#           [ 3.3710e-01, -5.1017e-01],
#           [ 7.5428e-01, -6.1327e-01]],
#
#          [[ 6.6540e-01, -6.4378e-01],
#           [-3.2032e-01,  9.7969e-01],
#           [-7.4930e-01, -3.6560e-01]],
#
#          [[ 1.7359e+00, -7.9830e-01],
#           [ 5.1931e-01, -2.7567e-01],
#           [-4.7254e-01, -7.1090e-01]],
#
#          [[ 5.5081e-01, -3.8192e-01],
#           [-2.7967e-02, -2.1647e+00],
#           [ 8.6138e-01,  1.5220e-01]]],
#
#
# ...

# %%
weights = F.softmax(score, dim=-1)

# %%
weights.sum(dim=-1)
# Out:
# tensor([[[1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000],
#          [1.0000, 1.0000, 1.0000]]])
